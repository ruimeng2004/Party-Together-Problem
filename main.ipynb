# %% [markdown]
# # CSC4120 Project - Party Together Problem
#
# You can play with the code in the notebook.

# %%
from ptp_cli import *
# from utils import *
# from student_utils import *
# from ptp_solver import *

# %%
ptp_cli = PTP_CLI(input_dir="./inputs")
print(ptp_cli.HELP_MESSAGE)

# %%
ptp_cli.run()

# %%
ptp_cli.test_ptp_all()
